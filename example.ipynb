# %%
import numpy as np
import matplotlib.pyplot as plt

points = np.random.random_sample((10,2))
print(points)
plt.scatter(*points.T)
# Out:
# [[0.39314256 0.25902274]
#  [0.98390971 0.30810063]
#  [0.10714357 0.64811794]
#  [0.66395534 0.35816978]
#  [0.47238244 0.46657015]
#  [0.53148828 0.98731465]
#  [0.77362877 0.31461131]
#  [0.42144866 0.1610096 ]
#  [0.76019756 0.88926148]
#  [0.14480306 0.79716668]]
